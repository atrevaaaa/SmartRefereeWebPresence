# %%
# import a utility function for loading Roboflow models
from inference import get_model, InferencePipeline
# import supervision to visualize our results
import supervision as sv
# import cv2 to helo load our image
import cv2
import numpy as np

import pandas as pd
import imageio

from inference.core.interfaces.camera.entities import VideoFrame

ball_bboxes = []
ball_bboxes_large_crop = []

rim_bboxes = []
person_bboxes = []


# custom prediction handler that adds the ball's bounding box data to the dataframe for each video frame
def handle_prediction_shot(p: dict, video_frame: VideoFrame):
    seen_ball = False
    seen_rim = False
        
    for obj in p['predictions']:
        if obj['class'] == "ball" and not seen_ball:
            seen_ball = True
            ball_bboxes.append( np.array([obj['x'] - obj['width'] // 2, obj['y'] - obj['height'] //2, obj['x'] + obj['width'] // 2, obj['y'] + obj['height'] // 2 ]) )
        elif obj['class'] == "rim" and not seen_rim:
            seen_rim = True
            rim_bboxes.append( np.array([obj['x'] - obj['width'] // 2, obj['y'] - obj['height'] // 2, obj['x'] + obj['width'] // 2, obj['y'] + obj['height'] // 2 ]) )
    if not seen_ball:
        ball_bboxes.append(np.zeros((4,)) - 1)
    if not seen_rim:
        rim_bboxes.append(np.zeros((4,)) - 1)



# custom prediction handler that adds the ball's bounding box data to the dataframe for each video frame
def handle_prediction_person(p: dict, video_frame: VideoFrame):
    frame_person_bboxes = []
    seen_ball = False

    for obj in p['predictions']:
        if obj['class'] == "ball" and not seen_ball:
            seen_ball = True
            ball_bboxes_large_crop.append( np.array([obj['x'] - obj['width'] // 2, obj['y'] - obj['height'] //2, obj['x'] + obj['width'] // 2, obj['y'] + obj['height'] // 2 ]) )
        if obj['class'] == "person":
            frame_person_bboxes.append(np.array([obj['x'] - obj['width'] // 2, obj['y'] - obj['height'] // 2, obj['x'] + obj['width'] // 2, obj['y'] + obj['height'] // 2 ]) )
    if not seen_ball:
        ball_bboxes_large_crop.append(np.zeros((4,)) - 1)
    person_bboxes.append(frame_person_bboxes)
    
        
api_key = "IRP2OLTd8fdWQqhQLHaV"

uncropped_video_path = "/home/alex/Downloads/input.MOV" ### uncropped version for person

pipeline = InferencePipeline.init(
    model_id="basketball-w2xcw/1",
    video_reference=uncropped_video_path,
    on_prediction=handle_prediction_person,
    api_key=api_key
)

pipeline.start()
pipeline.join()

cropped_video_path = "/home/alex/Downloads/output.mov" ### cropped version for shot

pipeline = InferencePipeline.init(
    model_id="basketball-w2xcw/1",
    video_reference=cropped_video_path,
    on_prediction=handle_prediction_shot,
    api_key=api_key
)

pipeline.start()
pipeline.join()

rim_bboxes = np.stack(rim_bboxes)
ball_bboxes = np.stack(ball_bboxes)
ball_bboxes_large_crop = np.stack(ball_bboxes_large_crop)

# %%
np.save("rim_bboxes.npy", rim_bboxes)
np.save("ball_bboxes.npy", ball_bboxes)
# Convert the list of lists to an object array
array_to_save = np.empty(len(person_bboxes), dtype=object)
for i, sublist in enumerate(person_bboxes):
    array_to_save[i] = np.array(sublist, dtype=object)

np.save("person_bboxes.npy", array_to_save)

# %%
frame.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 frame.shape
#
# NameError: name 'frame' is not defined

# %%
adjustment = np.array([frame.shape[1] // 4, frame.shape[0] // 4, frame.shape[1] // 4, frame.shape[0] //4 ])

# %%
import cv2
import numpy as np
def crop_image_with_padding(output_image, y1, y2, x1, x2, vertical_added_pixels, horizontal_added_pixels):
    # Get image dimensions
    H, W = output_image.shape[:2]
    
    # Calculate new coordinates with added pixels, ensuring they stay within bounds
    new_y1 = max(0, int(y1) - vertical_added_pixels)
    new_y2 = min(H, int(y2) + vertical_added_pixels)
    new_x1 = max(0, int(x1) - horizontal_added_pixels)
    new_x2 = min(W, int(x2) + horizontal_added_pixels)
    
    # Crop the image using the new coordinates
    cropped_image = output_image[new_y1:new_y2, new_x1:new_x2]
    
    return cropped_image
    
def get_shirt_color(image, bboxes):
    """
    Segments crops from image using bboxes.
    Returns the average pixel intensity of the region corresponding to t-shirt
    """
    # Make a copy of the image to avoid modifying the original
    output_image = image.copy()

    # Loop through the list of bounding boxes and draw each one
    dists = []
    
    for bbox in bboxes:
        x1, y1, x2, y2 = bbox
        cropped_image = crop_image_with_padding(output_image, y1, y2, x1, x2, 50, 50)
        mask = generate_mask( cropped_image, "t-shirt")
        if np.prod(mask.shape) > 0:
            mask = mask[0]
            dists.append( (cropped_image[mask]/255).mean() )
        else:
            dists.append(None)
    return dists

# %%
reader = imageio.get_reader("/home/alex/Downloads/input.MOV")

for i, frame in enumerate(reader): 
    if i < len(shirt_colors):
        continue
    shirt_color = get_shirt_color(frame, person_bboxes[i])
    shirt_colors.append(shirt_color)
# Out:
# 0: 1024x640 21 objects, 34.8ms
# Speed: 2.3ms preprocess, 34.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 29 objects, 40.0ms
# Speed: 2.1ms preprocess, 40.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 26 objects, 34.7ms
# Speed: 2.0ms preprocess, 34.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 22 objects, 32.2ms
# Speed: 2.2ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 22 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 24 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 23 objects, 33.9ms
# Speed: 1.9ms preprocess, 33.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 26 objects, 28.2ms
# Speed: 2.0ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 24 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 19 objects, 25.8ms
# Speed: 1.5ms preprocess, 25.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 23 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 25 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 20 objects, 37.1ms
# Speed: 2.2ms preprocess, 37.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 23 objects, 25.8ms
# Speed: 1.6ms preprocess, 25.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 21 objects, 42.3ms
# Speed: 2.6ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 27 objects, 26.9ms
# Speed: 1.6ms preprocess, 26.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 19 objects, 42.4ms
# Speed: 2.7ms preprocess, 42.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 28 objects, 25.8ms
# Speed: 1.8ms preprocess, 25.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x800 17 objects, 43.9ms
# Speed: 2.4ms preprocess, 43.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 24 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 25 objects, 42.2ms
# Speed: 2.7ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 22 objects, 25.8ms
# Speed: 1.5ms preprocess, 25.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 23 objects, 37.1ms
# Speed: 2.1ms preprocess, 37.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 16 objects, 27.0ms
# Speed: 1.6ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 22 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 22 objects, 30.7ms
# Speed: 2.2ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 27 objects, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 24 objects, 34.1ms
# Speed: 2.0ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 26 objects, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 23 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 31 objects, 37.2ms
# Speed: 2.1ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 23 objects, 34.7ms
# Speed: 2.0ms preprocess, 34.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 29 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 25 objects, 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 29 objects, 34.2ms
# Speed: 2.3ms preprocess, 34.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 24 objects, 37.2ms
# Speed: 2.1ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 23 objects, 34.1ms
# Speed: 2.0ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 28 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 20 objects, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 25 objects, 42.5ms
# Speed: 2.2ms preprocess, 42.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 21 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 21 objects, 42.5ms
# Speed: 2.1ms preprocess, 42.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 20 objects, 30.7ms
# Speed: 2.1ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x800 23 objects, 43.9ms
# Speed: 2.2ms preprocess, 43.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 19 objects, 28.2ms
# Speed: 2.1ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x800 23 objects, 43.8ms
# Speed: 2.2ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 19 objects, 42.2ms
# Speed: 2.7ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 23 objects, 26.8ms
# Speed: 1.6ms preprocess, 26.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 19 objects, 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 18 objects, 25.8ms
# Speed: 1.8ms preprocess, 25.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 22 objects, 34.7ms
# Speed: 2.0ms preprocess, 34.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 21 objects, 25.8ms
# Speed: 1.5ms preprocess, 25.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 17 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 21 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 14 objects, 37.1ms
# Speed: 2.1ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 19 objects, 25.8ms
# Speed: 1.5ms preprocess, 25.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x800 13 objects, 43.8ms
# Speed: 2.7ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 23 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 16 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 20 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 16 objects, 37.1ms
# Speed: 2.1ms preprocess, 37.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 28 objects, 34.1ms
# Speed: 2.4ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 20 objects, 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 33 objects, 37.1ms
# Speed: 2.1ms preprocess, 37.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 32 objects, 42.6ms
# Speed: 2.2ms preprocess, 42.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 13 objects, 37.2ms
# Speed: 2.1ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 31 objects, 42.3ms
# Speed: 2.7ms preprocess, 42.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 17 objects, 42.2ms
# Speed: 2.1ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 25 objects, 42.3ms
# Speed: 2.7ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x800 11 objects, 43.8ms
# Speed: 2.7ms preprocess, 43.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 25 objects, 37.2ms
# Speed: 2.1ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x832 15 objects, 44.9ms
# Speed: 2.9ms preprocess, 44.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 27 objects, 37.2ms
# Speed: 2.1ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x896 18 objects, 47.9ms
# Speed: 2.4ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x800 30 objects, 43.6ms
# Speed: 2.2ms preprocess, 43.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x896 18 objects, 47.7ms
# Speed: 2.4ms preprocess, 47.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x800 26 objects, 43.6ms
# Speed: 2.8ms preprocess, 43.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x832 16 objects, 44.9ms
# Speed: 2.2ms preprocess, 44.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 26 objects, 42.2ms
# Speed: 2.1ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 15 objects, 42.2ms
# Speed: 2.6ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 23 objects, 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 16 objects, 42.3ms
# Speed: 2.1ms preprocess, 42.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 15 objects, 42.3ms
# Speed: 2.1ms preprocess, 42.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 26 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 16 objects, 42.2ms
# Speed: 2.1ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 30 objects, 27.0ms
# Speed: 1.6ms preprocess, 27.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 16 objects, 42.2ms
# Speed: 2.6ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 24 objects, 25.8ms
# Speed: 1.5ms preprocess, 25.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 10 objects, 37.1ms
# Speed: 2.5ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 23 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 13 objects, 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 25 objects, 25.7ms
# Speed: 1.9ms preprocess, 25.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 11 objects, 34.8ms
# Speed: 2.5ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 24 objects, 25.7ms
# Speed: 1.5ms preprocess, 25.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 14 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 27 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 18 objects, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 32 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 15 objects, 34.2ms
# Speed: 1.9ms preprocess, 34.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 34 objects, 34.2ms
# Speed: 1.9ms preprocess, 34.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 31 objects, 34.9ms
# Speed: 2.0ms preprocess, 34.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 13 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 25 objects, 34.1ms
# Speed: 2.0ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 14 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 29 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 12 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 27 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 8 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 27 objects, 37.2ms
# Speed: 2.1ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 18 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 25 objects, 42.2ms
# Speed: 2.7ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 18 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 22 objects, 42.3ms
# Speed: 2.8ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 17 objects, 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 24 objects, 42.2ms
# Speed: 2.6ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 14 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 26 objects, 42.3ms
# Speed: 2.6ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 14 objects, 37.1ms
# Speed: 2.4ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 27 objects, 42.3ms
# Speed: 2.1ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 13 objects, 37.1ms
# Speed: 2.4ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 26 objects, 37.2ms
# Speed: 2.1ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 16 objects, 37.2ms
# Speed: 1.9ms preprocess, 37.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 23 objects, 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 13 objects, 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 21 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 10 objects, 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 20 objects, 34.8ms
# Speed: 2.4ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 12 objects, 34.1ms
# Speed: 2.0ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 26 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 12 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 33 objects, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 15 objects, 27.0ms
# Speed: 2.4ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 27 objects, 34.1ms
# Speed: 2.0ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 20 objects, 25.8ms
# Speed: 1.8ms preprocess, 25.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 27 objects, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 20 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 30 objects, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 21 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 28 objects, 32.2ms
# Speed: 2.1ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 24 objects, 25.3ms
# Speed: 1.4ms preprocess, 25.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 27 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 16 objects, 25.7ms
# Speed: 1.5ms preprocess, 25.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 27 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 21 objects, 25.8ms
# Speed: 1.5ms preprocess, 25.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 17 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 31 objects, 30.7ms
# Speed: 2.1ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 24 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 17 objects, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 12 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 29 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 28 objects, 30.8ms
# Speed: 1.8ms preprocess, 30.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 14 objects, 37.2ms
# Speed: 1.9ms preprocess, 37.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 11 objects, 34.9ms
# Speed: 1.9ms preprocess, 34.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 29 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 26 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 14 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 30 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x800 11 objects, 43.8ms
# Speed: 2.0ms preprocess, 43.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 15 objects, 42.2ms
# Speed: 2.0ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 30 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 14 objects, 37.1ms
# Speed: 1.9ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 17 objects, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 16 objects, 34.2ms
# Speed: 2.3ms preprocess, 34.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 29 objects, 28.1ms
# Speed: 2.0ms preprocess, 28.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 12 objects, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 29 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 16 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 26 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 15 objects, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 17 objects, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 27 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 12 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 2.1ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 9 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 31 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 15 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 30 objects, 28.3ms
# Speed: 1.7ms preprocess, 28.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 16 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.3ms
# Speed: 1.8ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 10 objects, 30.7ms
# Speed: 2.1ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 32 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 11 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 26 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 15 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 24 objects, 28.2ms
# Speed: 1.8ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 17 objects, 34.1ms
# Speed: 2.2ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 27 objects, 30.7ms
# Speed: 2.0ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 19 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 34 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 12 objects, 37.1ms
# Speed: 1.9ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 32 objects, 30.8ms
# Speed: 1.8ms preprocess, 30.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 21 objects, 37.2ms
# Speed: 2.5ms preprocess, 37.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 30 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 11 objects, 37.1ms
# Speed: 2.1ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 31 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x768 12 objects, 42.3ms
# Speed: 2.0ms preprocess, 42.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 34 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 14 objects, 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 31 objects, 30.7ms
# Speed: 2.1ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x736 19 objects, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 27 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 20 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 31 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 16 objects, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 30 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 22 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 31 objects, 28.2ms
# Speed: 2.1ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 19 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 34 objects, 28.2ms
# Speed: 2.1ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 18 objects, 28.4ms
# Speed: 2.0ms preprocess, 28.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 30 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 17 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 29 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 17 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 13 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 27 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 14 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 18 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 34 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 17 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 15 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 23 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 18 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 26 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 18 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 14 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 33 objects, 30.7ms
# Speed: 2.1ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 17 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 28 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 18 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 33 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 14 objects, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 28 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 15 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 30 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 17 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 28 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 16 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 24 objects, 28.1ms
# Speed: 1.6ms preprocess, 28.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 16 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 23 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 13 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 26 objects, 28.2ms
# Speed: 2.1ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 14 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 26 objects, 30.8ms
# Speed: 1.7ms preprocess, 30.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 15 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 29 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 16 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.1ms
# Speed: 2.1ms preprocess, 28.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 15 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 25 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 22 objects, 30.7ms
# Speed: 2.0ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 27 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 22 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.1ms
# Speed: 1.6ms preprocess, 28.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 20 objects, 28.3ms
# Speed: 1.5ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 29 objects, 26.9ms
# Speed: 1.6ms preprocess, 26.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 21 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 33 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 18 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 35 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 16 objects, 28.2ms
# Speed: 1.5ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 36 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 17 objects, 28.2ms
# Speed: 1.5ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 33 objects, 28.1ms
# Speed: 1.7ms preprocess, 28.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 20 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 30 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 17 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 33 objects, 30.7ms
# Speed: 1.9ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 22 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 30 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 22 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 26 objects, 30.8ms
# Speed: 1.8ms preprocess, 30.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 23 objects, 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 29 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 24 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 25 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 22 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 23 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 22 objects, 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 23 objects, 32.2ms
# Speed: 2.2ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 24 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 22 objects, 30.7ms
# Speed: 2.2ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 25 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 26 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 25 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 23 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 21 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 23 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 27 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 24 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 23 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 23 objects, 30.7ms
# Speed: 1.9ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 25 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 29 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 19 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 27 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 23 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 28 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 18 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 19 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 27 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 28 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 26 objects, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 26 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 30 objects, 28.2ms
# Speed: 2.1ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 20 objects, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 2.1ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 19 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.3ms
# Speed: 2.0ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 27 objects, 28.3ms
# Speed: 1.7ms preprocess, 28.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 23 objects, 28.2ms
# Speed: 1.5ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 24 objects, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 15 objects, 28.2ms
# Speed: 1.8ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 28 objects, 28.3ms
# Speed: 1.7ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 19 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 25 objects, 27.0ms
# Speed: 1.6ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 17 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 27 objects, 26.9ms
# Speed: 1.6ms preprocess, 26.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 21 objects, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 26 objects, 27.0ms
# Speed: 1.6ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 17 objects, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 27 objects, 26.9ms
# Speed: 1.6ms preprocess, 26.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 22 objects, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 26 objects, 26.9ms
# Speed: 1.6ms preprocess, 26.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 21 objects, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 27 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 18 objects, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 26 objects, 28.2ms
# Speed: 1.7ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 16 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 27 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 19 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 30 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 20 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 28 objects, 30.7ms
# Speed: 2.1ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 18 objects, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 32 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 15 objects, 34.1ms
# Speed: 2.2ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 31 objects, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 28 objects, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 20 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 18 objects, 32.2ms
# Speed: 2.3ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 27 objects, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 20 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 27 objects, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 20 objects, 28.1ms
# Speed: 1.6ms preprocess, 28.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 26 objects, 34.2ms
# Speed: 1.9ms preprocess, 34.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 20 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 23 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 21 objects, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 22 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 24 objects, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 13 objects, 30.7ms
# Speed: 1.6ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 28 objects, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 13 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 18 objects, 32.2ms
# ...
#
# 0: 1024x992 24 objects, 51.9ms
# Speed: 2.6ms preprocess, 51.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 17 objects, 34.3ms
# Speed: 1.8ms preprocess, 34.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 16 objects, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x992 24 objects, 51.7ms
# Speed: 2.6ms preprocess, 51.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x992 22 objects, 51.9ms
# Speed: 2.5ms preprocess, 51.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 18 objects, 30.8ms
# Speed: 1.7ms preprocess, 30.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 22 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 19 objects, 28.4ms
# Speed: 1.6ms preprocess, 28.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x992 24 objects, 51.9ms
# Speed: 2.6ms preprocess, 51.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 18 objects, 27.1ms
# Speed: 1.8ms preprocess, 27.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 14 objects, 27.1ms
# Speed: 1.6ms preprocess, 27.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 22 objects, 52.6ms
# Speed: 2.6ms preprocess, 52.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 22 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 17 objects, 25.9ms
# Speed: 1.5ms preprocess, 25.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 11 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 25 objects, 52.6ms
# Speed: 2.6ms preprocess, 52.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 13 objects, 25.4ms
# Speed: 1.4ms preprocess, 25.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 24 objects, 52.7ms
# Speed: 2.7ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 23 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 14 objects, 25.4ms
# Speed: 1.4ms preprocess, 25.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 13 objects, 25.3ms
# Speed: 1.5ms preprocess, 25.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 24 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 14 objects, 25.4ms
# Speed: 1.5ms preprocess, 25.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 24 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 20 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 25 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 14 objects, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 22 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x480 18 objects, 25.4ms
# Speed: 1.4ms preprocess, 25.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 24 objects, 52.8ms
# Speed: 2.6ms preprocess, 52.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 16 objects, 25.9ms
# Speed: 1.9ms preprocess, 25.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 19 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 16 objects, 25.9ms
# Speed: 1.5ms preprocess, 25.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 19 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x512 13 objects, 25.9ms
# Speed: 1.5ms preprocess, 25.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 21 objects, 52.6ms
# Speed: 2.6ms preprocess, 52.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 11 objects, 27.1ms
# Speed: 1.5ms preprocess, 27.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 20 objects, 52.6ms
# Speed: 2.6ms preprocess, 52.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 11 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 21 objects, 52.6ms
# Speed: 2.6ms preprocess, 52.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 10 objects, 30.8ms
# Speed: 2.0ms preprocess, 30.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 19 objects, 52.4ms
# Speed: 2.6ms preprocess, 52.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 13 objects, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 19 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 15 objects, 34.3ms
# Speed: 1.8ms preprocess, 34.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 20 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x704 15 objects, 35.0ms
# Speed: 1.9ms preprocess, 35.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 19 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 12 objects, 34.3ms
# Speed: 2.3ms preprocess, 34.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 992x1024 18 objects, 51.8ms
# Speed: 2.5ms preprocess, 51.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 15 objects, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 20 objects, 52.6ms
# Speed: 2.6ms preprocess, 52.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 13 objects, 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 19 objects, 52.7ms
# Speed: 2.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 12 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 960x1024 19 objects, 51.1ms
# Speed: 2.4ms preprocess, 51.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 12 objects, 27.1ms
# Speed: 1.5ms preprocess, 27.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 960x1024 19 objects, 51.2ms
# Speed: 2.4ms preprocess, 51.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 9 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 960x1024 18 objects, 51.0ms
# Speed: 2.4ms preprocess, 51.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 12 objects, 28.4ms
# Speed: 1.6ms preprocess, 28.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 960x1024 20 objects, 51.2ms
# Speed: 2.4ms preprocess, 51.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 20 objects, 50.3ms
# Speed: 3.0ms preprocess, 50.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 17 objects, 32.3ms
# Speed: 1.6ms preprocess, 32.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 18 objects, 50.1ms
# Speed: 3.0ms preprocess, 50.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x640 8 objects, 32.2ms
# Speed: 1.6ms preprocess, 32.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 11 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 20 objects, 50.3ms
# Speed: 3.0ms preprocess, 50.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 15 objects, 28.4ms
# Speed: 1.6ms preprocess, 28.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 18 objects, 50.3ms
# Speed: 3.0ms preprocess, 50.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 13 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 16 objects, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 13 objects, 28.4ms
# Speed: 1.6ms preprocess, 28.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 19 objects, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 12 objects, 28.3ms
# Speed: 1.9ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 16 objects, 50.2ms
# Speed: 3.0ms preprocess, 50.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 13 objects, 27.1ms
# Speed: 1.5ms preprocess, 27.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 896x1024 16 objects, 89.1ms
# Speed: 2.9ms preprocess, 89.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 11 objects, 28.2ms
# Speed: 2.0ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 17 objects, 50.2ms
# Speed: 3.0ms preprocess, 50.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 13 objects, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 18 objects, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 15 objects, 27.1ms
# Speed: 1.5ms preprocess, 27.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 20 objects, 50.2ms
# Speed: 3.1ms preprocess, 50.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 12 objects, 27.1ms
# Speed: 1.5ms preprocess, 27.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 896x1024 19 objects, 48.0ms
# Speed: 2.9ms preprocess, 48.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 14 objects, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 896x1024 18 objects, 48.0ms
# Speed: 2.9ms preprocess, 48.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x544 16 objects, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 896x1024 20 objects, 48.2ms
# Speed: 2.9ms preprocess, 48.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 18 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 21 objects, 50.1ms
# Speed: 3.0ms preprocess, 50.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 17 objects, 28.4ms
# Speed: 1.5ms preprocess, 28.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 960x1024 16 objects, 51.1ms
# Speed: 2.5ms preprocess, 51.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 10 objects, 28.4ms
# Speed: 1.6ms preprocess, 28.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 992x1024 15 objects, 51.7ms
# Speed: 2.5ms preprocess, 51.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 11 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 992x1024 14 objects, 51.8ms
# Speed: 2.5ms preprocess, 51.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 13 objects, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 14 objects, 30.8ms
# Speed: 1.7ms preprocess, 30.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 15 objects, 30.8ms
# Speed: 1.7ms preprocess, 30.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 992x1024 17 objects, 51.8ms
# Speed: 2.5ms preprocess, 51.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 13 objects, 28.4ms
# Speed: 1.6ms preprocess, 28.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 992x1024 15 objects, 51.8ms
# Speed: 2.6ms preprocess, 51.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x576 14 objects, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 960x1024 14 objects, 51.2ms
# Speed: 2.5ms preprocess, 51.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x608 12 objects, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 960x1024 17 objects, 51.2ms
# Speed: 2.5ms preprocess, 51.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 14 objects, 34.3ms
# Speed: 1.8ms preprocess, 34.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 928x1024 15 objects, 50.0ms
# Speed: 3.1ms preprocess, 50.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 12 objects, 34.2ms
# Speed: 1.9ms preprocess, 34.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x864 16 objects, 46.4ms
# Speed: 2.8ms preprocess, 46.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 16 objects, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x864 16 objects, 46.7ms
# Speed: 2.8ms preprocess, 46.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x960 17 objects, 51.1ms
# Speed: 2.5ms preprocess, 51.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x672 21 objects, 34.3ms
# Speed: 1.8ms preprocess, 34.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[98], line 6
#       4 if i < len(shirt_colors):
#       5     continue
# ----> 6 shirt_color = get_shirt_color(frame, person_bboxes[i])
#       7 shirt_colors.append(shirt_color)
#
# Cell In[95], line 33, in get_shirt_color(image, bboxes)
#      31 cropped_image = crop_image_with_padding(output_image, y1, y2, x1, x2, 50, 50)
#      32 mask = generate_mask( cropped_image, "t-shirt")
# ---> 33 if np.prod(mask.shape) > 0:
#      34     mask = mask[0]
#      35     dists.append( (cropped_image[mask]/255).mean() )
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
def distance_between_bboxes(bbox1, bbox2):
    # Extract the coordinates of the corners of bbox1
    x1_min, y1_min, x1_max, y1_max = bbox1
    x2_min, y2_min, x2_max, y2_max = bbox2
    
    # Compute distances in the x and y directions
    dx = max(x1_min - x2_max, x2_min - x1_max, 0)
    dy = max(y1_min - y2_max, y2_min - y1_max, 0)
    
    # If the bounding boxes overlap, dx and/or dy will be negative or zero
    # When they overlap, the distance is zero
    distance = np.sqrt(dx**2 + dy**2)
    
    return distance

# %%
final_ball_bboxes = np.copy(ball_bboxes_large_crop)
better_version_mask = ~((ball_bboxes) == -1).all(axis=-1)
final_ball_bboxes[better_version_mask] = ball_bboxes[better_version_mask] + adjustment

# %%
ball_bboxes_uncropped = final_ball_bboxes
ball_bboxes_uncropped[ball_bboxes_uncropped == -1] = -1

white_distance_to_ball = []
black_distance_to_ball = []

for shirt_color, person_bbox, ball_bbox in zip(shirt_colors, person_bboxes[:len(shirt_colors)], ball_bboxes_uncropped[:len(shirt_colors)]):
    if (ball_bbox == -1).all():
        white_distance_to_ball.append(-1)
        black_distance_to_ball.append(-1)
    elif len(person_bbox) == 1:
        dist = distance_between_bboxes(person_bbox[0], ball_bbox)
        if shirt_color[0] < 0.5:
            black_distance_to_ball.append(dist)
            white_distance_to_ball.append(-1)
        else:
            white_distance_to_ball.append(dist)
            black_distance_to_ball.append(-1)           
    else:
        ball_dists = [ distance_between_bboxes(person, ball_bbox) for person in person_bbox ]
        if len(ball_dists) > 2:
            sorted_indices = sorted(range(len(ball_dists)), key=lambda i: ball_dists[i], reverse=False)[:2]
            shirt_color = [shirt_color[i] for i in sorted_indices]
            ball_dists = [ball_dists[i] for i in sorted_indices]
        black_index = np.argmin(shirt_color)
        white_index = (black_index + 1) % 2
        
        white_distance_to_ball.append(ball_dists[white_index])
        black_distance_to_ball.append(ball_dists[black_index])

white_distance_to_ball = np.stack(white_distance_to_ball)
black_distance_to_ball = np.stack(black_distance_to_ball)

# %%
import mediapy
import cv2
import numpy as np
from IPython.display import display, Video
#frames = np.stack(frames_orig)

def create_video_with_bboxes(video_path, bboxes, ball_bboxes, output_file='output_video.mp4', window_size = 15):
    # Assume frames is a numpy array of shape (num_frames, height, width, channels)
    # and bboxes is a numpy array of shape (num_frames, 4) with each row [x1, y1, x2, y2]
    reader = imageio.get_reader(video_path)
    current_score_index = -1 * np.inf
    
    first_frame = reader.get_data(0)
    height, width = first_frame.shape[:2]

    ball_points = calculate_central_points(ball_bboxes)
    
    # Define the codec and create a VideoWriter object with MP4 format
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # 'mp4v' (or 'x264' might also be used)
    out = cv2.VideoWriter(output_file, fourcc, 20.0, (width, height))
    white_points_count = 0
    black_points_count = 0
    
    # Loop through each frame and the corresponding bbox
    for i, frame in enumerate(reader): #frame, bbox in zip(frames, bboxes):
        if i > white_distance_to_ball.shape[0]:
            break
        bbox = bboxes[i]

        metadata = reader.get_meta_data(i)
        timestamp = metadata.get('timestamp', None)  # Attempt to get the timestamp

        calc_ball_trajectory = False
        
        if i > window_size // 2:
            current_points = ball_points[i - window_size // 2 :i + window_size // 2 + 1].astype(np.int64)
            nearby_last = np.sqrt( ( (current_points - current_points[-1,None])**2).sum(-1) ) < 300
            mask = np.all( current_points > 0, axis = -1)  
            mask = np.logical_and(mask, nearby_last)
            current_points = current_points[mask]
            if current_points.shape[0] > 2:
                ball_line_points = line_of_best_fit(current_points).astype(np.int64)
                calc_ball_trajectory = True
                try:
                    cv2.line(frame, ball_line_points[0], ball_line_points[1], (255, 0, 0), 2)
                    for point in current_points:
                        cv2.circle(frame, point, radius=1, color=(0, 255, 0), thickness=21)  # A green point
                except:
                    pass
        
        # Convert frame to RGB (OpenCV uses BGR by default)
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        
        # Draw the bounding box on the frame
        # Bbox coordinates are assumed to be (x1, y1, x2, y2)
        if np.all(bbox > 0):
            rim_bbox = True
            horizontal_line_at_percentile(bbox, 40)
            rim_line_points = horizontal_line_at_percentile(bbox, 40)
            cv2.line(frame, rim_line_points[0], rim_line_points[1], (255, 0, 0), 2)
            cv2.rectangle(frame, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (0, 255, 0), 2)
        else:
            rim_bbox = False

        if rim_bbox and calc_ball_trajectory:
            intersection, point = find_intersection(ball_line_points[0],ball_line_points[1], rim_line_points[0], rim_line_points[1])
            slope1 = (ball_line_points[0] - ball_line_points[1])
            slope1 = slope1 / ( np.linalg.norm(slope1) + 1e-8)

            slope2 = (np.array(rim_line_points[0]) - np.array(rim_line_points[1]))
            slope2 = slope2 / np.linalg.norm(slope2)
            
            dot_product = np.abs( (slope1 * slope2).sum() )
            ball_line_height = current_points[0, 1]
            rim_height = rim_line_points[0][1]

            rim_check = ball_line_height <= rim_height
            if intersection and i - current_score_index > 40: #and rim_check: ### 100 frames since last point
                cv2.circle(frame, (int(point[0]), int(point[1])), radius=1, color=(255, 0, 0), thickness=21)  #
                print("POINT!", i, point)
                print(ball_line_height, rim_height)
                current_score_index = i
                white_recent_distance = white_distance_to_ball[i-100:i]
                low_ball_mask = ball_points[i-100:i][...,0] > frame.shape[0] // 2
                white_recent_distance = white_recent_distance[np.logical_and( white_recent_distance != -1, low_ball_mask)].mean()
                white_recent_distance = np.inf if white_recent_distance == np.nan else white_recent_distance
                
                black_recent_distance = black_distance_to_ball[i-100:i]
                black_recent_distance = black_recent_distance[np.logical_and( black_recent_distance != -1, low_ball_mask)].mean()
                black_recent_distance = np.inf if black_recent_distance == np.nan else black_recent_distance

                if white_recent_distance < black_recent_distance:
                    print("WHITE")
                    white_points_count += 1
                else:
                    print("BLACK")
                    black_points_count += 1
        points_string = f'white: {white_points_count}' + "   " + f'black: {black_points_count}'
        cv2.putText(frame, points_string, (width - 700, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 0), 2, cv2.LINE_AA)
        
        # Write the frame with the bbox into the file
        out.write(frame)
    
    # Release everything when job is finished
    out.release()
    cv2.destroyAllWindows()
    
    # Display the video in the notebook
    #mediapy.show_video(imageio.mimread(output_file), height=800)


# Create and display the video
create_video_with_bboxes(uncropped_video_path, rim_bboxes + adjustment, ball_bboxes_uncropped, window_size=10)
# Out:
# POINT! 429 [     1023.1         554]
# 522 554
# BLACK
# POINT! 542 [     1017.5         553]
# 513 553
# BLACK
# POINT! 686 [     1014.4         554]
# 517 554
# WHITE
# POINT! 1069 [     1014.6         555]
# 508 555
# BLACK
# RuntimeWarning: invalid value encountered in divide
# POINT! 1240 [     1019.8         554]
# 505 554
# BLACK
# POINT! 1383 [     1013.5         554]
# 491 554
# WHITE
# POINT! 1794 [     1032.4         551]
# 555 551
# WHITE
# POINT! 2009 [     1016.7         553]
# 522 553
# BLACK
# POINT! 2448 [       1017         554]
# 521 554
# BLACK
# RuntimeWarning: invalid value encountered in scalar divide
# RuntimeWarning: invalid value encountered in cast
# POINT! 2553 [       1013         554]
# 556 554
# BLACK
# POINT! 2708 [       1012         554]
# 714 554
# WHITE
# POINT! 2901 [     1020.7         554]
# 510 554
# WHITE
# POINT! 3110 [     1021.2         554]
# 523 554
# BLACK
# POINT! 3262 [       1015         553]
# 511 553
# WHITE
# POINT! 3556 [     1011.6         552]
# 527 552
# WHITE
# POINT! 3749 [     1020.4         553]
# 488 553
# WHITE
# POINT! 3924 [       1017         554]
# 561 554
# BLACK
# POINT! 4087 [     1020.1         554]
# 497 554
# BLACK
# POINT! 4289 [     1017.3         554]
# 519 554
# BLACK
# POINT! 4467 [     1012.3         553]
# 503 553
# WHITE
# POINT! 4845 [     1025.3         553]
# 494 553
# WHITE
# POINT! 5124 [     1011.6         553]
# 492 553
# WHITE

# %%
ball_line_points = np.array([[777, 604],
       [820, 332]])

rim_line_points = ((879, 550), (1065, 550))

import numpy as np

def find_intersection(p1, q1, p2, q2):
    """
    Find the intersection point of two line segments p1q1 and p2q2, if it exists.
    
    p1, q1: Endpoints of the first line segment (numpy arrays).
    p2, q2: Endpoints of the second line segment (numpy arrays).
    
    Returns:
    (bool, array): A tuple where the first element is True if the segments intersect,
                   and the second element is the intersection point as a numpy array.
    """
    # Convert input points to numpy arrays if they aren't already
    p1, q1, p2, q2 = map(np.array, [p1, q1, p2, q2])

    # Vector from p1 to q1
    d1 = q1 - p1
    # Vector from p2 to q2
    d2 = q2 - p2
    # Perpendicular vector to d2
    d2_perp = np.array([-d2[1], d2[0]])

    # Solve the equation p1 + t * d1 = p2 + s * d2
    # Rearrange to (p1 - p2) = s * d2 - t * d1
    # Project onto d2_perp: (p1 - p2) . d2_perp = s * d2 . d2_perp (because d1 . d2_perp = 0)
    denom = np.dot(d1, d2_perp)
    if denom == 0:
        return (False, None)  # Parallel or collinear

    # Scalar projection of (p2 - p1) onto d2_perp
    num = np.dot(p2 - p1, d2_perp)
    t = num / denom

    # Check if the intersection point is on the segment p1q1
    if t < 0 or t > 1:
        return (False, None)

    # Find intersection point
    intersection_point = p1 + t * d1

    # Check if the intersection point is on the segment p2q2
    if not (min(p2[0], q2[0]) <= intersection_point[0] <= max(p2[0], q2[0]) and
            min(p2[1], q2[1]) <= intersection_point[1] <= max(p2[1], q2[1])):
        return (False, None)

    return (True, intersection_point)

from numpy import array

intersection, point = find_intersection(*(array([806, 504]), array([867, 446]), (880, 545), (1068, 545)))
print("Intersection:", intersection, "Point:", point)

def plot_rays(p1, q1, p2, q2, intersection):
    """Plot the two rays and the intersection if exists."""
    fig, ax = plt.subplots()

    # Calculate direction vectors
    d1 = np.array(q1) - np.array(p1)
    d2 = np.array(q2) - np.array(p2)

    # Extend lines for better visualization
    line1_end = np.array(p1) + d1
    line2_end = np.array(p2) + d2

    # Plotting the rays from their starting points to the extended points
    ax.plot([p1[0], line1_end[0]], [p1[1], line1_end[1]], 'r-', label='Ray 1')
    ax.plot([p2[0], line2_end[0]], [p2[1], line2_end[1]], 'b-', label='Ray 2')

    # Plot intersection if exists
    if intersection[0]:
        ax.plot(intersection[1][0], intersection[1][1], 'go', label='Intersection')

    ax.plot(p1[0], p1[1], 'ro')  # Start of ray 1
    ax.plot(p2[0], p2[1], 'bo')  # Start of ray 2

    ax.set_title("Visualization of Two Rays")
    ax.legend()
    ax.set_aspect('equal')
    plt.grid(True)
    plt.show()
# Out:
# Intersection: False Point: None

# %%
import torch
import matplotlib.pyplot as plt

def line_of_best_fit(points):
    """Calculate the line of best fit for given 2D points."""
    # Ensure points are a torch tensor of the right shape (N, 2)
    #points = np.array(points, dtype=np.float32)
    
    # Extract x and y coordinates
    x = points[:, 0]
    y = points[:, 1]
    
    # Calculate the coefficients for the line y = mx + b
    x_mean = x.mean()
    y_mean = y.mean()
    numerator = np.dot((x - x_mean), (y - y_mean))
    denominator = np.dot((x - x_mean), (x - x_mean))
    m = numerator / denominator
    b = y_mean - m * x_mean
    
    # Determine the x-range for the line endpoints
    x_min, x_max = x.min(), x.max()
    
    # Calculate corresponding y values at x_min and x_max
    y_min = m * x_min + b
    y_max = m * x_max + b
    
    # Create endpoints of the line
    line_endpoints = np.array([[x_min, y_min], [x_max, y_max]])
    
    return line_endpoints

def visualize_line_of_best_fit(points):
    """Visualize the points and the line of best fit."""
    # Calculate the line of best fit endpoints
    line_endpoints = line_of_best_fit(points)
    
    # Convert to numpy for plotting
    points_np = points.numpy()
    line_endpoints_np = line_endpoints
    
    # Plotting the points
    plt.figure(figsize=(8, 6))
    plt.scatter(points_np[:, 0], points_np[:, 1], color='blue', label='Data Points')
    
    # Plotting the line of best fit
    plt.plot(line_endpoints_np[:, 0], line_endpoints_np[:, 1], 'r-', label='Line of Best Fit')
    
    plt.title('Line of Best Fit')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example points
points = torch.tensor([[1, 2], [2, 3], [4, 3], [5, 5], [6, 8]], dtype=torch.float32)

# Visualize the points and the line of best fit
visualize_line_of_best_fit(points)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def calculate_central_points(bboxes):
    """Calculate the central points of bounding boxes."""
    # Convert to a PyTorch tensor if not already one
    
    # Calculate central points (x_center, y_center)
    x_center = (bboxes[:, 0] + bboxes[:, 2]) / 2
    y_center = (bboxes[:, 1] + bboxes[:, 3]) / 2
    
    # Stack the central points into a (N, 2) tensor
    return np.stack((x_center, y_center), axis=1)

def horizontal_line_at_percentile(bbox, percentile):
    """
    Calculate a horizontal line that is a given percentile from the top of the bbox.
    
    Parameters:
    - bbox: Tuple of (x_min, y_min, x_max, y_max)
    - percentile: Float (0-100), the percentile from the top of the bbox
    
    Returns:
    - Tuple containing the coordinates of both endpoints of the horizontal line: 
      ((x_start, y), (x_end, y))
    """
    x_min, y_min, x_max, y_max = bbox
    # Calculate the y-coordinate at the given percentile from the top
    y = y_min + (y_max - y_min) * (percentile / 100.0)

    # Create endpoints of the horizontal line
    line_start = (int(x_min), int(y))
    line_end = (int(x_max), int(y))
    
    return (line_start, line_end)

def visualize_horizontal_line(bbox, percentile):
    """
    Visualize the bounding box and a horizontal line at a specified percentile from the top.
    """
    fig, ax = plt.subplots()
    # Draw the bounding box
    rect = patches.Rectangle((bbox[0], bbox[1]), bbox[2] - bbox[0], bbox[3] - bbox[1], linewidth=2, edgecolor='r', facecolor='none')
    ax.add_patch(rect)

    # Calculate the horizontal line
    line = horizontal_line_at_percentile(bbox, percentile)
    line_start, line_end = line

    # Draw the horizontal line
    plt.plot([line_start[0], line_end[0]], [line_start[1], line_end[1]], 'b-', label=f'{percentile}% line')

    # Set the limits of the plot to slightly beyond the bbox dimensions
    plt.xlim(bbox[0] - 10, bbox[2] + 10)
    plt.ylim(bbox[1] - 10, bbox[3] + 10)

    # Add grid, legend, and labels
    plt.grid(True)
    plt.legend()
    plt.title('Bounding Box and Horizontal Line at Percentile')
    plt.xlabel('X coordinate')
    plt.ylabel('Y coordinate')
    plt.show()

# Example bounding box and percentile
bbox = (10, 20, 100, 200)
percentile = 25

# Visualize the bounding box and the horizontal line at 25% from the top
visualize_horizontal_line(bbox, percentile)

# %%
import os
import sys
from PIL import Image

# Add the parent directory to the Python path
parent_dir = os.path.abspath( '..')
sys.path.append(parent_dir)
import torch
from PIL import Image
import ast
from fastsam import FastSAM, FastSAMPrompt
from utils.tools import convert_box_xywh_to_xyxy
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import clip
clip_model, preprocess = clip.load('ViT-B/32', device=device) ### WHY DID THEY DO THIS EVERY TIME!!

def call_text_prompt(prompt_process, text):
    if prompt_process.results == None:
        return []
    format_results = prompt_process._format_results(prompt_process.results[0], 0)
    cropped_boxes, cropped_images, not_crop, filter_id, annotations = prompt_process._crop_image(format_results)
    scores = prompt_process.retrieve(clip_model, preprocess, cropped_boxes, text, device=prompt_process.device)
    max_idx = scores.argsort()
    max_idx = max_idx[-1]
    max_idx += sum(np.array(filter_id) <= int(max_idx))
    return np.array([annotations[max_idx]['segmentation']])

class ModelWrapper:
    def __init__(self, model_path, device):
        self.model = FastSAM(model_path)
        self.device = device

    def get_mask(self, input_img, text_prompt=None, point_prompt="[[0,0]]", point_label="[0]", box_prompt="[[0,0,0,0]]", imgsz=1024, iou=0.9, conf=0.4, retina=True, withContours=False, better_quality=False):
        point_prompt = ast.literal_eval(point_prompt)
        box_prompt = convert_box_xywh_to_xyxy(ast.literal_eval(box_prompt))
        point_label = ast.literal_eval(point_label)
        
        everything_results = self.model(
            input_img,
            device=self.device,
            retina_masks=retina,
            imgsz=imgsz,
            conf=conf,
            iou=iou    
        )
        
        bboxes = None
        points = None
        point_label = None
        prompt_process = FastSAMPrompt(input_img, everything_results, device=self.device)
        ann = call_text_prompt(prompt_process, text=text_prompt)
        
        return ann

# Initialize the model once
model_path = '../weights/FastSAM.pt'
model_wrapper = ModelWrapper(model_path, device)

def generate_mask(img_path, text_prompt):
    return model_wrapper.get_mask(img_path, text_prompt)

img = imageio.imread('../roboflow/black_shirt.png')

# Example usage
mask = generate_mask(img, 'shirt')
# Out:
# DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#
# 0: 1024x256 13 objects, 91.2ms
# Speed: 4.7ms preprocess, 91.2ms inference, 257.9ms postprocess per image at shape (1, 3, 1024, 1024)

# %%
import matplotlib.pyplot as plt
plt.imshow(mask[0])
